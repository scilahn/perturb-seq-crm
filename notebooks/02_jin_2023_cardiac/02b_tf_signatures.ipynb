# %% [markdown]
# # 02b — Jin 2023 Cardiac: TF Signatures
#
# **Dataset:** Jin 2023 cardiac iPSC-CM TFs
# **Accession:** GSE222980
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Characterize transcription factor perturbation signatures; identify cardiac TF regulatory programs; compare with known TF targets.
