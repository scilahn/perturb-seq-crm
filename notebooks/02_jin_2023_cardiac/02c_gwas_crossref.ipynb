# %% [markdown]
# # 02c — Jin 2023 Cardiac: GWAS Cross-Reference
#
# **Dataset:** Jin 2023 cardiac iPSC-CM TFs
# **Accession:** GSE222980
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Map cardiac GWAS loci to perturbed TFs; identify GWAS-nominated genes lacking perturbation data as novel hypothesis targets.
