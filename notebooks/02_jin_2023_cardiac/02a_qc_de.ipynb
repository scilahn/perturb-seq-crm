# %% [markdown]
# # 02a — Jin 2023 Cardiac: QC and DE
#
# **Dataset:** Jin 2023 cardiac iPSC-CM TFs
# **Accession:** GSE222980
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Apply Phase 2 QC and pseudobulk DE pipeline to Jin 2023 cardiac TF perturbation dataset.
