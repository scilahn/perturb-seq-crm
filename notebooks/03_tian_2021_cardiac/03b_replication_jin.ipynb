# %% [markdown]
# # 03b — Tian 2021 Cardiac: Replication of Jin Findings
#
# **Dataset:** TianKampmann2021_CRISPRi (scPerturb-harmonized)
# **Accession:** GSE124703
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Test whether cardiac TF perturbation effects observed in Jin 2023 replicate in the Tian 2021 iPSC-neuron dataset; identify conserved vs. context-specific effects.
