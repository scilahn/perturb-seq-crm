# %% [markdown]
# # 03a — Tian 2021 Cardiac: QC and DE
#
# **Dataset:** TianKampmann2021_CRISPRi (scPerturb-harmonized)
# **Accession:** GSE124703
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Apply Phase 2 QC and pseudobulk DE pipeline to Tian 2021 large-scale CRISPRi cardiac dataset; focus on lysosomal/ferroptosis pathways relevant to cardiac ischemia.
