# %% [markdown]
# # cd_01 — Cross-Dataset: Harmonized Differential Expression
#
# **Dataset:** All Tier 1 scPerturb datasets
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Cross-dataset harmonized DE restricted to shared gene universe; compare effect directions across cardiac datasets (Jin, Tian, Replogle).
