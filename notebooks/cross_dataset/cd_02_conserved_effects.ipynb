# %% [markdown]
# # cd_02 — Cross-Dataset: Conserved Perturbation Effects
#
# **Dataset:** All Tier 1 scPerturb datasets
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Identify perturbations with conserved transcriptional effects across cardiac datasets vs. those with context-specific effects.
