# %% [markdown]
# # cd_03 — Cross-Dataset: GWAS Mapping
#
# **Dataset:** All Tier 1 scPerturb datasets
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Pull cardiac, renal, and metabolic GWAS catalog entries; map loci to genes via Open Targets; intersect with perturbed gene lists; flag high-priority hypothesis targets.
