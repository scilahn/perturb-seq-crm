# %% [markdown]
# # 04a — Xu 2023 Renal: QC and DE
#
# **Dataset:** Xu 2023 kidney organoid CRISPRi
# **Accession:** GSE217246
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Apply QC and pseudobulk DE pipeline to Xu 2023 kidney organoid CRISPRi dataset; characterize renal tubular and podocyte perturbation effects.
