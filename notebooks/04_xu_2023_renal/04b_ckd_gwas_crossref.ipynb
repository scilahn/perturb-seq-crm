# %% [markdown]
# # 04b — Xu 2023 Renal: CKD GWAS Cross-Reference
#
# **Dataset:** Xu 2023 kidney organoid CRISPRi
# **Accession:** GSE217246
# **Phase:** 3
# **Date:** 2026-03-11
# **Objective:** Map CKD and eGFR GWAS loci to perturbed genes in kidney organoids; identify renal GWAS candidates for novel hypothesis testing.
